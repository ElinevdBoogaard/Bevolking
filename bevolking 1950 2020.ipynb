# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("C:/Users/eline/Documents/Coursera/data analyst/test/bevolking.xlsx")

# %%
df.head()
# Out:
#    Perioden  Bevolking naar geslacht/Totale bevolking (aantal)  \
# 0      1950                                           10026773
# 1      1960                                           11417254
# 2      1970                                           12957621
# 3      1980                                           14091014
# 4      1990                                           14892574
#
#    Bevolking naar geslacht/Mannen (aantal)  \
# 0                                  4998251
# 1                                  5686152
# 2                                  6465081
# 3                                  6994280
# 4                                  7358482
#
#    Bevolking naar geslacht/Vrouwen (aantal)  \
# 0                                   5028522
# 1                                   5731102
# 2                                   6492540
# 3                                   7096734
# 4                                   7534092
#
# ...

# %%
df.set_index("Perioden", inplace = True) #gerund

# %%
df[["Bevolking naar geslacht/Mannen (aantal)", "Bevolking naar geslacht/Vrouwen (aantal)"]].plot(kind="line")
plt.title("Nederlandse bevolking naar geslacht 1950-2020")
# Out:
# Text(0.5, 1.0, 'Nederlandse bevolking naar geslacht 1950-2020')

# %%
df[["Bevolkingsdichtheid (aantal)"]].plot(kind="line")
plt.title("Bevolkingsdichtheid in Nederland 1950-2020")
# Out:
# Text(0.5, 1.0, 'Bevolkingsdichtheid in Nederland 1950-2020')
